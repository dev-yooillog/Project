# %% [markdown]
# ### Korean Sentiment Analysis
# Dataset: Naver Sentiment Movie Corpus (NSMC)
# - 영화 리뷰 데이터를 이용한 감성 분석
# - 긍정 / 부정 분류

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_style("whitegrid")

# %%
BASE_DIR = Path("..")

train_path = BASE_DIR / "data" / "ratings_train.txt"
test_path = BASE_DIR / "data" / "ratings_test.txt"

train = pd.read_csv(train_path, sep="\t")
test = pd.read_csv(test_path, sep="\t")

# %%
print("Train shape:", train.shape)
print("Test shape:", test.shape)
# Out:
# Train shape: (150000, 3)
# Test shape: (50000, 3)

# %%
train.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
train.isnull().sum()
# Out:
# id          0
# document    5
# label       0
# dtype: int64

# %%
train = train.dropna()

# %%
train["label"].value_counts()
# Out:
# label
# 0    75170
# 1    74825
# Name: count, dtype: int64

# %%
sns.countplot(x="label", data=train)
plt.title("Label Distribution")
plt.show()

# %%
train.sample(10)
# Out:
#               id                                       document  label
# 99150    3741150                    아름다운 이자벨(마고)... 영화는 너무 어수선~      0
# 82528    9913958             음...좋군! 원치않는 시간여행자의 '아내' 아내가 제목이다ㅠ      1
# 149286   6036417  1.2 가 워낙 재밋어서 비교하긴 그렇치만..이것도 매우 볼만한 영화인건 틀림없다      1
# 115300   9590587                                노두소덕슨노돋봊솢솢논곧논복숙      1
# 19034    8419469                                  중고딩들이나 좋아할 영화      0
# 89812    6892136                                            자미무      1
# 32844   10064933                  실화바탕이라 더 최고임! 보고있으면 엄청 집중하게 됨      1
# 50026    6440692                                           굿!!!      1
# 106435   5819061   정말최악 쓰레기중쓰레기.KTX인데영화시끄러워서잠도안오네.철도공사 정말각성해야함.      0
# 20523     717498                                      진짜 시간 아깝다      0
